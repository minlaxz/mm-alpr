# %%
import cv2
import pickle
import time
from pympler import asizeof
import sys

# %%
import numpy as np

# %%
img = cv2.imread('predicted.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
print(sys.getsizeof(img))
print(len(pickle.dumps(img)))
print(asizeof.asizeof(img))
# Out:
# 958592
# 958628
# 958608

# %%
# img2 = np.frombuffer(img.tobytes(), dtype="B").reshape((320,240,3),)

# %%
encode_param = [int(cv2.IMWRITE_JPEG_QUALITY), 90]
result, encimg = cv2.imencode('.jpg', img, encode_param)

# %%
type(encimg)
# Out:
# numpy.ndarray

# %%
print(sys.getsizeof(encimg))
print(len(pickle.dumps(encimg)))
print(asizeof.asizeof(encimg))
# Out:
# 61301
# 61350
# 61320

# %%
plt.imshow(encimg)

# %%
decimg = cv2.imdecode(encimg, 1)

# %%
plt.imshow(decimg)

# %%
print(sys.getsizeof(decimg))
print(len(pickle.dumps(decimg)))
print(asizeof.asizeof(decimg))
# Out:
# 958592
# 958628
# 958608
